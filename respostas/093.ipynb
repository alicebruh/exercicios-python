# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebruh/exercicios-python/blob/main/respostas/093.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
v = []
for i in range(10):
  v.append(int(input(f"Digite o elemento {i+1} do vetor: ")))
v.reverse()
print(f"O vetor na ordem inversa:", end="")
for i in v:
  print(f" {i}", end="")
# Out:
# Digite o elemento 1 do vetor: 1
# Digite o elemento 2 do vetor: 2
# Digite o elemento 3 do vetor: 3
# Digite o elemento 4 do vetor: 4
# Digite o elemento 5 do vetor: 5
# Digite o elemento 6 do vetor: 6
# Digite o elemento 7 do vetor: 67
# Digite o elemento 8 do vetor: 8
# Digite o elemento 9 do vetor: 9
# Digite o elemento 10 do vetor: 10
# O vetor na ordem inversa: 10 9 8 67 6 5 4 3 2 1
