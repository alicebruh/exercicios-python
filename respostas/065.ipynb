# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebruh/exercicios-python/blob/main/respostas/065.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Digite um número inteiro: "))
p = "É"
for i in range(n):
  if ((i+1 != 1 and i+1 != n) and n % (i+1) == 0):
    p = "Não é"
    break
print(f"{p} primo")
# Out:
# Digite um número inteiro: 12
# Não é primo
