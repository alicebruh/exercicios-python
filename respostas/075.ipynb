# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebruh/exercicios-python/blob/main/respostas/075.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
p = ''
while True:
  c = 1
  i = 1
  s = 0
  while c != 0:
    c = float(input(f"Digite o preço do Produto {i}: R$"))
    i += 1
    s += c
  print(f"O valor total da compra é: R${s:.2f}")
  v = float(input(f"Valor do Pagamento: R$"))
  print(f"Troco: R${(v-s):.2f}")
  p = input("Deseja realizar mais uma compra (S/N) ? ")
  if(p == 'N'):
    break
# Out:
# Digite o preço do Produto 1: R$3.80
# Digite o preço do Produto 2: R$5.20
# Digite o preço do Produto 3: R$0
# O valor total da compra é: R$9.00
# Valor do Pagamento: R$20
# Troco: R$11.00
# Deseja realizar mais uma compra (S/N) ? S
# Digite o preço do Produto 1: R$5
# Digite o preço do Produto 2: R$6
# Digite o preço do Produto 3: R$7
# Digite o preço do Produto 4: R$0
# O valor total da compra é: R$18.00
# Valor do Pagamento: R$20
# Troco: R$2.00
# Deseja realizar mais uma compra (S/N) ? N
