# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebruh/exercicios-python/blob/main/respostas/020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = float(input("Digite um valor: "))
if (x > 0):
  print(f"{x} é um número positivo")
elif (x < 0):
  print(f"{x} é um número negativo")
else:
  print(f"{x} é igual a zero")
# Out:
# Digite um valor: 2
# 2.0 é um número positivo
