# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebruh/exercicios-python/blob/main/respostas/023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n1 = float(input("Primeira nota: "))
n2 = float(input("Segunda nota: "))
m = (n1+n2)/2
if (m >= 7 and m < 10):
  print("Aprovado")
elif(m == 10):
  print("Aprovado com Distinção")
else:
  print("Reprovado")
# Out:
# Primeira nota: 9
# Segunda nota: 9
# Aprovado
