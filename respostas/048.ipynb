# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebruh/exercicios-python/blob/main/respostas/048.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = input("Nome: ")
while(len(n) <= 3):
  n = input("Dado Invalido! Digite o nome novamente: ")

i = int(input("Idade: "))
while(i < 0 or i > 150):
  i = int(input("Dado Invalido! Digite a idade novamente: "))

s = int(input("Salário: "))
while(s <= 0):
  s = int(input("Dado Invalido! Digite o salário novamente: "))

e = input("Estado Civil: ").lower()
while(e != 's' and e != 'c' and e != 'd' and e != 'v'):
  e = input("Dado Invalido! Digite o estado civil novamente: ").lower()
# Out:
# Nome: Alice
# Idade: 17
# Salário: 2
# Estado Civil: sssss
# Dado Invalido! Digite o estado civil novamente: s
