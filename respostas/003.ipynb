# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebruh/exercicios-python/blob/main/respostas/003.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = int(input("Digite um número: "))
y = int(input("Digite outro número: "))
z = x+y
print("A soma entre {0} e {1} é igual a {2}!".format(x,y,z))
# Out:
# Digite um número: 2
# Digite outro número: 3
# A soma entre 2 e 3 é igual a 5!
