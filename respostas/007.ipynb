# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebruh/exercicios-python/blob/main/respostas/007.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l = int(input("Digite o valor do lado de um quadrado: "))
a = l**2
d = a*2
print("A área do quadrado de lado {} tem valor {}, e o dobro desta área é {}!".format(l,a,d))
# Out:
# Digite o valor do lado de um quadrado: 2
# A área do quadrado de lado 2 tem valor 4, e o dobro desta área é 8!
