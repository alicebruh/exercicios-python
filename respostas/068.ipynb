# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebruh/exercicios-python/blob/main/respostas/068.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Digite de quantas notas você deseja saber a média: "))
s = 0
for i in range(n):
  x = float(input("Nota: "))
  s += x
print(f"A média das notas é {(s/n):.2f}")
# Out:
# Digite de quantas notas você deseja saber a média: 4
# Nota: 3
# Nota: 5
# Nota: 6
# Nota: 1
# A média das notas é 3.75
