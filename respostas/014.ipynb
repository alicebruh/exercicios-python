# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebruh/exercicios-python/blob/main/respostas/014.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
p = float(input("Quantidade pescada, em quilogramas: "))
excesso = p-50
multa = 4*excesso
print("João Papo-de-Pescador pescou {:.2f}kg em excesso e teve uma multa de R${:.2f}".format(excesso,multa))
# Out:
# Quantidade pescada, em quilogramas: 50.5
# João Papo-de-Pescador pescou 0.50kg em excesso e teve uma multa de R$2.00
