# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebruh/exercicios-python/blob/main/respostas/016.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

a = float(input("Tamanho da área a ser pintada: "))
t = a/3
l = math.ceil(t/18)
print(f"Para pintar essa área, são necessárias {int(l)} latas, oque irá custar R${(l*80):.2f}")
# Out:
# Tamanho da área a ser pintada: 108
# Para pintar essa área, são necessárias 2 latas, oque irá custar R$160.00
