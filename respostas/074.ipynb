# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebruh/exercicios-python/blob/main/respostas/074.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
p = float(input("Preço do pão: "))
print("TABELA DE PREÇOS")
for i in range(50):
  print(f"{i+1} - R${((i+1)*p):.2f}")
# Out:
# Preço do pão: 0.18
# TABELA DE PREÇOS
# 1 - R$0.18
# 2 - R$0.36
# 3 - R$0.54
# 4 - R$0.72
# 5 - R$0.90
# 6 - R$1.08
# 7 - R$1.26
# 8 - R$1.44
# 9 - R$1.62
# 10 - R$1.80
# 11 - R$1.98
# 12 - R$2.16
# 13 - R$2.34
# 14 - R$2.52
# 15 - R$2.70
# 16 - R$2.88
# 17 - R$3.06
# 18 - R$3.24
# 19 - R$3.42
# 20 - R$3.60
# 21 - R$3.78
# 22 - R$3.96
# 23 - R$4.14
# 24 - R$4.32
# 25 - R$4.50
# 26 - R$4.68
# 27 - R$4.86
# 28 - R$5.04
# 29 - R$5.22
# 30 - R$5.40
# 31 - R$5.58
# 32 - R$5.76
# 33 - R$5.94
# 34 - R$6.12
# 35 - R$6.30
# 36 - R$6.48
# 37 - R$6.66
# 38 - R$6.84
# 39 - R$7.02
# 40 - R$7.20
# 41 - R$7.38
# 42 - R$7.56
# 43 - R$7.74
# 44 - R$7.92
# 45 - R$8.10
# 46 - R$8.28
# 47 - R$8.46
# 48 - R$8.64
# 49 - R$8.82
# 50 - R$9.00
