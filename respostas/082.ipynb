# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebruh/exercicios-python/blob/main/respostas/082.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
d = float(input("Insira o valor da dívida: "))
j = 0
q = 1

print("Valor da Dívida Valor dos Juros Quantidade de Parcelas  Valor da Parcela ")
for i in range(5):
  print(f"R${d+j:.2f}        {j}                {q}                     R${((d+j)/q):.2f}")
  q = ((i+1)*3)
  j = d*(((i+2)*5)/100)
# Out:
# Insira o valor da dívida: 1000
# Valor da Dívida Valor dos Juros Quantidade de Parcelas  Valor da Parcela
# R$1000.00        0                1                     R$1000.00
# R$1100.00        100.0                3                     R$366.67
# R$1150.00        150.0                6                     R$191.67
# R$1200.00        200.0                9                     R$133.33
# R$1250.00        250.0                12                     R$104.17
