# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebruh/exercicios-python/blob/main/respostas/061.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Digite o número o qual você quer saber o fatorial: "))
x = 1
for i in range(n):
  x *= n-i
print(f"O fatorial de {n} é {x}")
# Out:
# Digite o número o qual você quer saber o fatorial: 10
# O fatorial de 10 é 3628800
