# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebruh/exercicios-python/blob/main/respostas/039.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Digite um número inteiro: "))
if (n // 2 == 0):
  print("O número é par")
else:
  print("O número é ímpar")
# Out:
# Digite um número inteiro: 0
# O número é par
