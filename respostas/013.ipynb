# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebruh/exercicios-python/blob/main/respostas/013.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
h = float(input("Altura (em m): "))
m = (72.2*h) - 58
f = (62.1*h) - 44.7
print("Para essa altura, o peso ideal para um homem é {:.2f}kg e para uma mulher é {:.2f}kg".format(m,f))
# Out:
# Altura (em m): 1.70
# Para essa altura, o peso ideal para um homem é 64.74kg e para uma mulher é 60.87kg
