# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebruh/exercicios-python/blob/main/respostas/009.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f = float(input("Temperatura em Farenheit: "))
c = (5*(f-32)/9)
print("Temperatura em Celsius: {:.2f}".format(c))
# Out:
# Temperatura em Farenheit: 270
# Temperatura em Celsius: 132.2
