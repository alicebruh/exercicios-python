# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebruh/exercicios-python/blob/main/respostas/10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
c = float(input("Temperatura em Celsius: "))
f = (9*c/5)+32
print("Temperatura em Farenheit: {:.2f}".format(f))
# Out:
# Temperatura em Celsius: 27
# Temperatura em Farenheit: 80.60
