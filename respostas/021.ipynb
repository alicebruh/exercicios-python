# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebruh/exercicios-python/blob/main/respostas/021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = input("Digite F para feminino ou M para masculino: ")
if (x == 'F'):
  print("Feminino")
elif (x == 'M'):
  print("Masculino")
else:
  print("Sexo Inválido")
# Out:
# Digite F para feminino ou M para masculino: 3
# Sexo Inválido
