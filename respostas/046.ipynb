# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebruh/exercicios-python/blob/main/respostas/046.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = float(input("Digite uma nota entre zero e dez: "))

while (n < 0 or n > 10):
  n = float(input("Nota inválida! Tente novamente: "))
print("Nota válida!")
# Out:
# Digite uma nota entre zero e dez: -1
# Nota inválida! Tente novamente: 19
# Nota inválida! Tente novamente: 34
# Nota inválida! Tente novamente: 534523423
# Nota inválida! Tente novamente: 1
# Nota válida!
