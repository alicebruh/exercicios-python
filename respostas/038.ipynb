# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebruh/exercicios-python/blob/main/respostas/038.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = int(input("Valor do saque: "))
x1 = x2 = x3 = x4 = t1 = t2 = t3 = t4 = t5 = ""

#quant notas de 100
if (s // 100 > 0):
  c = s//100
  t1 = f"{c} nota(s) de 100\n"

#quant notas de 50 e 10
if ((s%100)//10 > 5):
  cq = ((s%100)//10)//5
  d = (s%100)//10 - 5
  t2 = f"{cq} nota de 50\n"
  t3 = f"{d} nota(s) de 10\n"
elif ((s%100)//10 == 5):
  cq = ((s%100)//10)//5
  t2 = f"{cq} nota de 50\n"
elif((s%100)//10 > 0):
  d = ((s%100)//10)
  t3 = f"{d} nota(s) de 10\n"

#quant notas de 5 e 1
if (s%10 > 5):
  cin = (s%10//5)
  u = (s%10) - 5
  t4 = f"{cin} nota de 5\n"
  t5 = f"{u} nota(s) de 1"
elif (s%10 == 5):
  cin = (s%10//5)
  t4 = f"{cin} nota de 5\n"
elif(s%10 > 0):
  u = (s%10)
  t5 = f"{u} nota(s) de 1"

print(f"Para sacar a quantia de {s}, o programa fornece:\n{t1}{t2}{t3}{t4}{t5}.")
# Out:
# Valor do saque: 399
# Para sacar a quantia de 399, o programa fornece:
# 3 nota(s) de 100
# 1 nota de 50
# 4 nota(s) de 10
# 1 nota de 5
# 4 nota(s) de 1.
