# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebruh/exercicios-python/blob/main/respostas/057.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Digite o número da tabuada que você deseja ver: "))
for i in range(10):
  print(f"{n} * {i+1} = {n*(i+1)}")
# Out:
# Digite o número da tabuada que você deseja ver: 1257
# 1257 * 1 = 1257
# 1257 * 2 = 2514
# 1257 * 3 = 3771
# 1257 * 4 = 5028
# 1257 * 5 = 6285
# 1257 * 6 = 7542
# 1257 * 7 = 8799
# 1257 * 8 = 10056
# 1257 * 9 = 11313
# 1257 * 10 = 12570
