# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebruh/exercicios-python/blob/main/respostas/092.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
v = []
for i in range(5):
  v.append(int(input(f"Digite o elemento número {i+1} do vetor: ")))
print(f"Os elementos do vetor são:", end="")
for i in v:
  print(f" {i}", end="")
# Out:
# Digite o elemento número 1 do vetor: 1
# Digite o elemento número 2 do vetor: 2
# Digite o elemento número 3 do vetor: 3
# Digite o elemento número 4 do vetor: 4
# Digite o elemento número 5 do vetor: 5
# Os elementos do vetor são: 1 2 3 4 5
