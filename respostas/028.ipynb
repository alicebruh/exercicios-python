# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebruh/exercicios-python/blob/main/respostas/028.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = input("Você estuda em qual turno? ").upper()
if (x == 'M'):
  print("Bom dia!")
elif(x =='V'):
  print("Boa Tarde!")
elif(x == 'N'):
  print("Boa Noite!")
else:
  print("Valor Inválido!")
# Out:
# Você estuda em qual turno? n
# Boa Noite!
