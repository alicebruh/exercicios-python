# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebruh/exercicios-python/blob/main/respostas/006.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
r = int(input("Digite o valor do raio de um círculo: "))
a = math.pi * (r**2)
print("A área do círculo de raio {} é igual a {:.2f}".format(r,a))
# Out:
# Digite o valor do raio de um círculo: 5
# A área do círculo de raio 5 é igual a 78.54
