# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebruh/exercicios-python/blob/main/respostas/053.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l = []
for i in range(5):
  n = float(input("Digite 5 números: "))
  l.append(n)
x = 0
for i in l:
  x += i
print(f"A soma dos números é: {x}")
print(f"A média dos números é: {x/5}")
# Out:
# Digite 5 números: 1
# Digite 5 números: 2
# Digite 5 números: 3
# Digite 5 números: 4
# Digite 5 números: 5
# A soma dos números é: 15.0
# A média dos números é: 3.0
