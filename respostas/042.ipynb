# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebruh/exercicios-python/blob/main/respostas/042.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
r = 0

p = input("Telefonou para a vítima? ").upper()
if (p == 'S'):
  r += 1
p = input("Esteve no local do crime? ").upper()
if (p == 'S'):
  r += 1
p = input("Mora perto da vítima? ").upper()
if (p == 'S'):
  r += 1
p = input("Devia para a vítima? ").upper()
if (p == 'S'):
  r += 1
p = input("Já trabalhou com a vítima? ").upper()
if (p == 'S'):
  r += 1

if (r == 5):
  print("Assassino")
elif (r > 2):
  print("Cúmplice")
elif (r == 2):
  print("Suspeita")
else:
  print("Inocente")
# Out:
# Telefonou para a vítima? s
# Esteve no local do crime? S
# Mora perto da vítima? s
# Devia para a vítima? n
# Já trabalhou com a vítima? n
# Cúmplice
