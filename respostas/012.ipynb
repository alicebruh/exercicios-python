# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebruh/exercicios-python/blob/main/respostas/012.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = float(input("Digite sua altura, em metros: "))
p = (72.7*a)-58
print("Seu peso ideal é {:.2f}kg".format(p))
# Out:
# Digite sua altura, em metros: 1.5
# Seu peso ideal é 51.05kg
