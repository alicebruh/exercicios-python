# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebruh/exercicios-python/blob/main/respostas/040.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
n = float(input("Digite um número: "))
if (n %1 == 0):
  print("Número inteiro")
print(n%1)
# Out:
# Digite um número: 12.5
# 0.5
