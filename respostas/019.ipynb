# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebruh/exercicios-python/blob/main/respostas/019.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = float(input("Digite um número: "))
y = float(input("Digite outro número: "))
if (x > y):
  print(x)
elif (x < y):
  print(y)
else:
  print("Os dois números são iguais")
# Out:
# Digite um número: 1
# Digite outro número: 2
# 2.0
