# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebruh/exercicios-python/blob/main/respostas/062.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from math import inf
n = int(input("Digite a quantidade de números no conjunto: "))
c = []
s = 0
mn = inf
mx = -inf
for i in range(n):
  x = int(input("Digite os números presentes no conjunto: "))
  c.append(x)
for i in c:
  if (i > mx):
    mx = i
  if (i < mn):
    mn = i
  s += i
print(f"O menor valor do conjunto é {mn}, o maior valor do conjunto é {mx}, e a soma dos valores dos conjuntos é {s}.")
# Out:
# Digite a quantidade de números no conjunto: 4
# Digite os números presentes no conjunto: 6
# Digite os números presentes no conjunto: 1
# Digite os números presentes no conjunto: 10
# Digite os números presentes no conjunto: 4
# O menor valor do conjunto é 1, o maior valor do conjunto é 10, e a soma dos valores dos conjuntos é 21.
