# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebruh/exercicios-python/blob/main/respostas/058.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
b = int(input("Digite a base: "))
e = int(input("Digite o expoente: "))

x = b

for i in range(e-1):
  x *= b
print(x)
# Out:
# Digite a base: 5
# Digite o expoente: 2
# 25
