# %% [markdown]
# <a href="https://colab.research.google.com/github/alicebruh/exercicios-python/blob/main/respostas/052.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from math import inf
x = -inf
t = []
for i in range(5):
  n = float(input("Digite 5 números: "))
  t.append(n)

for i in t:
  if(i > x):
    x = i

print(f"O número maior é {x}")
# Out:
# Digite 5 números: 5
# Digite 5 números: 4
# Digite 5 números: 3
# Digite 5 números: 2
# Digite 5 números: 1
# O número maior é 5.0
